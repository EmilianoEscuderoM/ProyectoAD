# %% [markdown]
# # Descripción

# %% [markdown]
# La región de Medio Oriente ha sido escenario de conflictos prolongados, cambios políticos bruscos y tensiones étnicas y religiosas. Estos factores contribuyen a una inestabilidad geopolítica significativa, afectando la seguridad, economía y la vida cotidiana de millones de personas. La guerra civil en Siria, que comenzó en 2011, ha causado una devastadora crisis humanitaria y ha tenido profundas implicaciones geopolíticas a nivel regional y global. La inestabilidad resultante ha afectado no solo a Siria sino también a los países vecinos y ha tenido repercusiones en Europa debido a la crisis de refugiados. La inestabilidad geopolítica en Medio Oriente es una de las problemáticas más complejas y prolongadas a nivel mundial. La región ha sido testigo de conflictos armados, revoluciones, intervenciones extranjeras y tensiones étnicas y religiosas. Estos factores han generado un ambiente de inseguridad y volatilidad que afecta tanto a los países de la región como a la comunidad internacional.

# %%
import pandas as pd

# %% [markdown]
# ### 1. Carga del Dataset elegido por el equipo:

# %%
df=pd.read_csv('../Dataset/geopolitical_instability_middle_east.csv', sep=',')
df
# Out:
#       Conflict_ID       Region         Conflict_Type  Start_Date    End_Date  \
# 0               1  Afghanistan             terrorism  2010-01-01         NaN
# 1               2  Afghanistan             civil war  2010-01-02  2023-01-01
# 2               3         Iran             terrorism  2010-01-03  2023-01-01
# 3               4         Iran  territorial conflict  2010-01-04  2023-01-01
# 4               5         Iraq             terrorism  2010-01-05  2023-01-01
# ...           ...          ...                   ...         ...         ...
# 9995         9996        Syria             terrorism  2037-05-14         NaN
# 9996         9997         Iran             terrorism  2037-05-15         NaN
# 9997         9998  Afghanistan  territorial conflict  2037-05-16         NaN
# 9998         9999        Syria  territorial conflict  2037-05-17         NaN
# 9999        10000  Afghanistan             civil war  2037-05-18  2023-01-01
#
# ...

# %% [markdown]
# ### 2. Mostrar la información general del dataset (info) y estadísticas descriptivas generales (describe):

# %%
# Información general del dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 37 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Conflict_ID                       10000 non-null  int64
#  1   Region                            10000 non-null  object
#  2   Conflict_Type                     10000 non-null  object
#  3   Start_Date                        10000 non-null  object
#  4   End_Date                          5012 non-null   object
#  5   Number_of_Incidents               10000 non-null  int64
#  6   Number_of_Deaths                  10000 non-null  int64
#  7   Intervention_ID                   10000 non-null  int64
#  8   Intervention_Country              10000 non-null  object
#  9   Intervention_Organization         10000 non-null  object
#  10  Intervention_Type                 10000 non-null  object
# ...

# %%
# Estadísticas descriptivas generales
print(df.describe())
# Out:
#        Conflict_ID  Number_of_Incidents  Number_of_Deaths  Intervention_ID  \
# count  10000.00000         10000.000000      10000.000000      10000.00000
# mean    5000.50000            50.052900        497.471300       5000.50000
# std     2886.89568            28.613692        289.219727       2886.89568
# min        1.00000             1.000000          0.000000          1.00000
# 25%     2500.75000            25.000000        245.000000       2500.75000
# 50%     5000.50000            50.000000        496.000000       5000.50000
# 75%     7500.25000            75.000000        747.000000       7500.25000
# max    10000.00000            99.000000        999.000000      10000.00000
#
#          Population  GDP_Per_Capita  Unemployment_Rate  Poverty_Index  \
# count  1.000000e+04    10000.000000       10000.000000   10000.000000
# mean   2.051769e+07    25235.060200          27.319484      32.528334
# std    1.127294e+07    14278.657358          13.036807      15.917012
# ...

# %% [markdown]
# ### 3. Tamaño del conjunto de datos:

# %%
# Tamaño del dataset
print(df.shape)
# Out:
# (10000, 37)

# %% [markdown]
# ### 4. Columnas que contiene y qué información tienen:

# %%
# Nombres de las columnas
print(df.columns)
# Out:
# Index(['Conflict_ID', 'Region', 'Conflict_Type', 'Start_Date', 'End_Date',
#        'Number_of_Incidents', 'Number_of_Deaths', 'Intervention_ID',
#        'Intervention_Country', 'Intervention_Organization',
#        'Intervention_Type', 'Intervention_Start_Date', 'Intervention_End_Date',
#        'Intervention_Success', 'Country', 'Population', 'GDP_Per_Capita',
#        'Unemployment_Rate', 'Poverty_Index', 'Literacy_Rate', 'Ethnic_Group',
#        'Main_Religion', 'Ethnic_Religious_Tension', 'Number_of_Conflicts',
#        'Last_Conflict_Date', 'Corruption_Index', 'Governance_Quality',
#        'Government_Transparency', 'Number_of_Scandals',
#        'Number_of_Displaced_People', 'Number_of_Refugees',
#        'Humanitarian_Needs', 'Access_to_Humanitarian_Aid',
#        'Technology_Use_in_Conflicts', 'Technological_Investment',
#        'Number_of_Data_Analysis_Projects', 'Data_Analysis_Effectiveness'],
#       dtype='object')

# %%
# Primeras filas del dataset para ver qué información contienen las columnas
print(df.head())
# Out:
#    Conflict_ID       Region         Conflict_Type  Start_Date    End_Date  \
# 0            1  Afghanistan             terrorism  2010-01-01         NaN
# 1            2  Afghanistan             civil war  2010-01-02  2023-01-01
# 2            3         Iran             terrorism  2010-01-03  2023-01-01
# 3            4         Iran  territorial conflict  2010-01-04  2023-01-01
# 4            5         Iraq             terrorism  2010-01-05  2023-01-01
#
#    Number_of_Incidents  Number_of_Deaths  Intervention_ID  \
# 0                   48               820                1
# 1                   18               284                2
# 2                   55                29                3
# 3                   14               458                4
# 4                   34               935                5
#
#   Intervention_Country Intervention_Organization  ... Government_Transparency  \
# 0                 Iraq                 Red Cross  ...                       8
# ...

# %% [markdown]
# ### 5. Qué tipos de datos:

# %%
# Tipos de datos de cada columna
print(df.dtypes)
# Out:
# Conflict_ID                           int64
# Region                               object
# Conflict_Type                        object
# Start_Date                           object
# End_Date                             object
# Number_of_Incidents                   int64
# Number_of_Deaths                      int64
# Intervention_ID                       int64
# Intervention_Country                 object
# Intervention_Organization            object
# Intervention_Type                    object
# Intervention_Start_Date              object
# Intervention_End_Date                object
# Intervention_Success                 object
# Country                              object
# Population                            int64
# GDP_Per_Capita                        int64
# Unemployment_Rate                   float64
# Poverty_Index                       float64
# Literacy_Rate                       float64
# Ethnic_Group                         object
# ...

# %% [markdown]
# ### 6. Visualizar los nans que contiene el dataset:

# %%
# Visualizar NaNs
print(df.isna().sum())
# Out:
# Conflict_ID                            0
# Region                                 0
# Conflict_Type                          0
# Start_Date                             0
# End_Date                            4988
# Number_of_Incidents                    0
# Number_of_Deaths                       0
# Intervention_ID                        0
# Intervention_Country                   0
# Intervention_Organization              0
# Intervention_Type                      0
# Intervention_Start_Date                0
# Intervention_End_Date               5049
# Intervention_Success                   0
# Country                                0
# Population                             0
# GDP_Per_Capita                         0
# Unemployment_Rate                      0
# Poverty_Index                          0
# Literacy_Rate                          0
# Ethnic_Group                           0
# Main_Religion                          0
# Ethnic_Religious_Tension               0
# ...

# %% [markdown]
# ### 7. Limpiar el dataset para que no queden NAN:

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#       Conflict_ID       Region         Conflict_Type  Start_Date    End_Date  \
# 2               3         Iran             terrorism  2010-01-03  2023-01-01
# 4               5         Iraq             terrorism  2010-01-05  2023-01-01
# 5               6         Iraq             civil war  2010-01-06  2023-01-01
# 10             11         Iran             civil war  2010-01-11  2023-01-01
# 11             12        Yemen  territorial conflict  2010-01-12  2023-01-01
# ...           ...          ...                   ...         ...         ...
# 9965         9966         Iraq             civil war  2037-04-14  2023-01-01
# 9966         9967         Iraq  territorial conflict  2037-04-15  2023-01-01
# 9967         9968         Iraq  territorial conflict  2037-04-16  2023-01-01
# 9977         9978        Syria             terrorism  2037-04-26  2023-01-01
# 9999        10000  Afghanistan             civil war  2037-05-18  2023-01-01
#
# ...

# %% [markdown]
# ### 8. Reindexar el dataset:

# %%
# Reindexar el dataset
df_cleaned = df_cleaned.reset_index(drop=True)
df_cleaned
# Out:
#       Conflict_ID       Region         Conflict_Type  Start_Date    End_Date  \
# 0               3         Iran             terrorism  2010-01-03  2023-01-01
# 1               5         Iraq             terrorism  2010-01-05  2023-01-01
# 2               6         Iraq             civil war  2010-01-06  2023-01-01
# 3              11         Iran             civil war  2010-01-11  2023-01-01
# 4              12        Yemen  territorial conflict  2010-01-12  2023-01-01
# ...           ...          ...                   ...         ...         ...
# 2460         9966         Iraq             civil war  2037-04-14  2023-01-01
# 2461         9967         Iraq  territorial conflict  2037-04-15  2023-01-01
# 2462         9968         Iraq  territorial conflict  2037-04-16  2023-01-01
# 2463         9978        Syria             terrorism  2037-04-26  2023-01-01
# 2464        10000  Afghanistan             civil war  2037-05-18  2023-01-01
#
# ...

# %% [markdown]
# ### 9. Renombrar las columnas para una mejor comprensión:

# %%
nuevos_nombres = {
    'Conflict_ID' : "ID_Conflicto", 
    'Region' : "Región", 
    'Conflict_Type' : "Tipo_de_Conflicto", 
    'Start_Date' : "Fecha_de_Inicio", 
    'End_Date' : "Fecha_de_Finalización",
    'Number_of_Incidents' : "Número_de_Incidentes", 
    'Number_of_Deaths' : "Número_de_Muertes", 
    'Intervention_ID' : "ID_Intervención",
    'Intervention_Country' : "País_de_Intervención", 
    'Intervention_Organization' : "Organización_de_Intervención",
    'Intervention_Type' : "Tipo_de_Intervención", 
    'Intervention_Start_Date' : "Fecha_de_Inicio_de_Intervención", 
    'Intervention_End_Date' : "Fecha_de_Finalización_de_Intervención",
    'Intervention_Success' : "Éxito_de_Intervención", 
    'Country' : "País", 
    'Population' : "Población", 
    'GDP_Per_Capita' : "PIB_Per_Cápita",
    'Unemployment_Rate' : "Tasa_de_Desempleo", 
    'Poverty_Index' : "Índice_de_Pobreza", 
    'Literacy_Rate' : "Tasa_de_Alfabetización", 
    'Ethnic_Group' : "Grupo_Étnico",
    'Main_Religion' : "Religión_Principal", 
    'Ethnic_Religious_Tension' : "Tensión_Étnica_y_Religiosa", 
    'Number_of_Conflicts' : "Número_de_Conflictos",
    'Last_Conflict_Date' : "Fecha_del_Último_Conflicto", 
    'Corruption_Index' : "Índice_de_Corrupción", 
    'Governance_Quality' : "Calidad_de_Gobernanza",
    'Government_Transparency' : "Transparencia_Gubernamental", 
    'Number_of_Scandals' : "Número_de_Escándalos",
    'Number_of_Displaced_People' : "Número_de_Personas_Desplazadas", 
    'Number_of_Refugees' : "Número_de_Refugiados",
    'Humanitarian_Needs' : "Necesidades_Humanitarias", 
    'Access_to_Humanitarian_Aid' : "Acceso_a_Ayuda_Humanitaria",
    'Technology_Use_in_Conflicts' : "Uso_de_Tecnología_en_Conflictos", 
    'Technological_Investment' : "Inversión_Tecnológica",
    'Number_of_Data_Analysis_Projects' : "Número_de_Proyectos_de_Análisis_de_Datos", 
    'Data_Analysis_Effectiveness' : "Eficacia_del_Análisis_de_Datos"
}

# Aplicar los nuevos nombres de las columnas
df_cleaned.rename(columns=nuevos_nombres, inplace=True)
